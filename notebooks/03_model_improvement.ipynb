# %% [markdown]
# # Ideas for improvement of model 2.2 (RF on num + 1 cat feature):
# - include additional categorical features !
# - tuning of hyperparameters of RF
# e.g. RandomForestRegressor(
#     n_estimators=500,
#     max_depth=10,
#     min_samples_leaf=3,
#     random_state=42
# )
# - try XGBoost or LightGBM
# - feature importance analysis
